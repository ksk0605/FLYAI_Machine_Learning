# %% [markdown]
# # Pandas
# ---
# * [pandas 링크](https://pandas.pydata.org/)
# * 피쳐가 col이 되게끔 데이터를 정리해야함
#
# <br>
# <img src="https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FN4NAc%2FbtqRoP1ml8o%2Fx4DD7ITezrXVcJKgEYR5a1%2Fimg.png" width="50%"/>
# <br>
#
# * 열하나는 series 로 가져옴
# * series 를 concate시키면 dataFrame 으로 합쳐지고 column과 index를 자동으로 생성되고 따로따로 부르는게 가능
#
# <br>
#
# <img src = "https://qiita-user-contents.imgix.net/https%3A%2F%2Fqiita-image-store.s3.ap-northeast-1.amazonaws.com%2F0%2F117479%2F2b0a2cd4-ca19-c6e4-13d4-6d213cd20e9d.png?ixlib=rb-4.0.0&auto=format&gif-q=60&q=75&w=1400&fit=max&s=6da58bae4bc76d57745efad43da188ef" width="50%"/>
# <br>
#
#
# * api와 data관점에서 부르는 용어가 다름

# %%
# !pip install pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '1.4.3'

# %%
sr = pd.Series([3,2,3,4,7], name='apple')
sr2 = pd.Series([3,5,3,4,8], name='banana')
type(sr)
# Out:
# pandas.core.series.Series

# %%
sr,sr2
# Out:
# (0    3
#  1    2
#  2    3
#  3    4
#  4    7
#  Name: apple, dtype: int64,
#  0    3
#  1    5
#  2    3
#  3    4
#  4    8
#  Name: banana, dtype: int64)

# %% [markdown]
# * 왼쪽이 인덱스 오른쪽이 데이터
# * series에서는 col이 아닌 name이라고 부름

# %%
sr3 = pd.Series([4,3,5,5,8], name = 'mango', index=['A','B','C','D','E'])

# %%
sr3
# Out:
# A    4
# B    3
# C    5
# D    5
# E    8
# Name: mango, dtype: int64

# %%
df = pd.concat([sr,sr2], axis=1)
#dataframe type

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#    apple  banana
# 0      3       3
# 1      2       5
# 2      3       3
# 3      4       4
# 4      7       8

# %%
pd.concat([sr,sr3], axis=1)
# Out:
#    apple  mango
# 0    3.0    NaN
# 1    2.0    NaN
# 2    3.0    NaN
# 3    4.0    NaN
# 4    7.0    NaN
# A    NaN    4.0
# B    NaN    3.0
# C    NaN    5.0
# D    NaN    5.0
# E    NaN    8.0

# %% [markdown]
# * 인덱스가 다르면 위와 같이 결합됨

# %%
data = [
    ['John', 'Tom', 'Alice'],
    [3,4,5],
    [True,False,True]
]
pd.DataFrame(data)
# Out:
#       0      1      2
# 0  John    Tom  Alice
# 1     3      4      5
# 2  True  False   True

# %% [markdown]
# * 컬럼별로 같은 데이터가 아니면 pandas 에선 사용할 수 없음

# %%
data2 = [
    ['John', 5, True],
    ['Tom',4,False],
    ['Alice',5,True]
]
pd.DataFrame(data2)
# Out:
#        0  1      2
# 0   John  5   True
# 1    Tom  4  False
# 2  Alice  5   True

# %% [markdown]
# * 위와 같은 형태여야만 사용가능

# %%
pd.DataFrame(data).T #Trans가능
# Out:
#        0  1      2
# 0   John  3   True
# 1    Tom  4  False
# 2  Alice  5   True

# %%
data = {
    'name' :['John', 'Tom', 'Alice'],
    'point':[3,4,5],
    'pass' :[True,False, True]
}
df = pd.DataFrame(data)
df
# Out:
#     name  point   pass
# 0   John      3   True
# 1    Tom      4  False
# 2  Alice      5   True

# %% [markdown]
# * 딕셔너리 형태로 저장하는게 일반적

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['name', 'point', 'pass'], dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
data2 = [
    ['John', 5, True],
    ['Tom',4,False],
    ['Alice',5,True]
]

df_x = pd.DataFrame(data2)
df_x.columns = ['Name','Point','Pass']
df_x
# Out:
#     Name  Point   Pass
# 0   John      5   True
# 1    Tom      4  False
# 2  Alice      5   True

# %% [markdown]
# * 위와 같이 column name을 지정할 수 있음

# %%
df_x = df_x.rename(columns={'Point':'Score'}) 
df_x
# Out:
#     Name  Score   Pass
# 0   John      5   True
# 1    Tom      4  False
# 2  Alice      5   True

# %% [markdown]
# * dict형태로 작성하여 명시적으로 하나씩 바꿔줄 수 있음

# %%
iris = pd.read_csv("./datasets/titanic.csv") #타이타닉 탑승자 data
iris.shape
# Out:
# (891, 12)

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# * 맨 위에 있는 데이터 5개를 통해 데이터의 형태를 알 수 있는 함수
# * 비어있는 자리는 NaN로 표기
# * matplotlib과는 다르게 다 받을 수 있음

# %%
iris.tail(15)
# Out:
#      PassengerId  Survived  Pclass  \
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 876                  Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                           Petroff, Mr. Nedelio    male  19.0      0
# 878                             Laleff, Mr. Kristo    male   NaN      0
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# ...

# %% [markdown]
# * 뒤에서 가져오기

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# * data의 전반적인 정보를 알 수 있는 함수
# * non-null : 비어있는 곳이 있는지 알 수 있음
# * age의 경우 891중 714개만 들어있음
# * 비어있는 데이터는 결측치(missing value라고 부름)
# * Dtype을 통해 data type을 알 수 있음

# %%
# 결측치검사

sr = iris.isna().sum(0) #각각의 값이 nan이니?+몇개나 있는지
sr
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# * 결측치만 따로 뽑아서 확인가능
# * 컬럼의 축을 True = 1/False = 0이라는 값을 내부적으로 가지고 있기 때문에 sum()을 사용할 시 몇개의 데이터가 비어있는지 알 수 있음

# %%
type(sr)
# Out:
# pandas.core.series.Series

# %%
sr.index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sr.values
# Out:
# array([  0,   0,   0,   0,   0, 177,   0,   0,   0,   0, 687,   2],
#       dtype=int64)

# %%
import matplotlib.pyplot as plt
#plt.xticks
plt.bar(sr.index, sr.values)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# * matplotlib을 통해 데이터를 시각화 할 수 있음

# %% [markdown]
# ## 인코딩
# ----
# * 머신러닝 알고리즘에 문자데이터를 넣을 수 없음
# * 따라서 숫자로 바꿔주는 작업을 인코딩이라고 한다.
# * 그러나 머신러닝 알고리즘은 0 1 2 3 이렇게 카테고리컬한데이터로 나눌시 가중치를 알아서 계산하는 문제가 생긴다
# * 이때 사용하는 것이 one-hot incoding
# * 순서가 없는 범주형 데이터는 one hot incoding을 사용하나 학점같이 순서가 있는 경우에는 그냥 하기도 한다

# %%
titanic = iris.copy()

# %% [raw]
# titanic

# %%
titanic["Embarked"] #column별로 series로 부를 수 있음
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
titanic["Embarked"].unique() # titanic.Embarked.unique() 도 가능
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
pd.get_dummies(titanic["Embarked"])
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %% [markdown]
# * column을 unique한 값으로 바꿔주고 해당하는 값에 1을 넣어줌

# %%
type(titanic[["Embarked", "Pclass"]])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic[["Embarked", "Pclass"]]
# Out:
#     Embarked  Pclass
# 0          S       3
# 1          C       1
# 2          S       3
# 3          S       1
# 4          S       3
# ..       ...     ...
# 886        S       2
# 887        S       1
# 888        S       3
# 889        C       1
# 890        Q       3
#
# [891 rows x 2 columns]

# %% [markdown]
# * DataFrame type으로 가져옴

# %%
titanic["Embarked"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %% [markdown]
# * series type으로 가져옴

# %% [markdown]
# ## Pandas Slicing

# %% [markdown]
# * 내가 원하는 행과 열을 가져오는 두가지 방법
#   * iloc : 숫자로 가져오기
#   * loc

# %%
titanic.iloc[0:5, -1]
# Out:
# 0    S
# 1    C
# 2    S
# 3    S
# 4    S
# Name: Embarked, dtype: object

# %% [markdown]
# * numpy의 index slicing과 동일한 방법

# %%
titanic.loc[ (titanic['Embarked']=='C') , :] # & titanic['Survived'] == 1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# * 원하는 값에 해당하는 정보만 가져올 수 있음
# * 일반적으로 더 많이 사용

# %%
titanic[0:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ## sorting

# %%
titanic.sort_index(axis=0, ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 890          891         0       3
# 889          890         1       1
# 888          889         0       3
# 887          888         1       1
# 886          887         0       2
# ..           ...       ...     ...
# 4              5         0       3
# 3              4         1       1
# 2              3         1       3
# 1              2         1       1
# 0              1         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 890                                Dooley, Mr. Patrick    male  32.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# * index를 기준으로 sorting이 가능

# %%
titanic.sort_values(by=['Age']) #Age를 기준으로 sorting
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# * value기준 sorting가능

# %%
titanic.sort_values(by=['Age','Fare'])
# Out:
#      PassengerId  Survived  Pclass  \
# 803          804         1       3
# 755          756         1       2
# 469          470         1       3
# 644          645         1       3
# 831          832         1       2
# ..           ...       ...     ...
# 306          307         1       1
# 334          335         1       1
# 31            32         1       1
# 527          528         0       1
# 557          558         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 803                    Thomas, Master. Assad Alexander    male  0.42      0
# 755                          Hamalainen, Master. Viljo    male  0.67      1
# 469                      Baclini, Miss. Helene Barbara  female  0.75      2
# 644                             Baclini, Miss. Eugenie  female  0.75      2
# 831                    Richards, Master. George Sibley    male  0.83      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Column Engineering
# ### 데이터 전처리

# %% [markdown]
# ### 컬럼추가

# %%
titanic['Family'] = titanic['SibSp'] + titanic['Parch']

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# * 없는 칼럼의 이름을 인덱스로 사용하면 col추가

# %%
titanic.drop(['SibSp','Parch'], axis=1, inplace = True) # 여러개는 list로 지정, 어느 축으로 삭제할건지 inplace = True를 지정하면 원본
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %% [markdown]
# * 여러개는 list로 지정
# * 어느 축으로 삭제할건지
# * inplace = True를 지정하면 원본변경

# %% [markdown]
# ### 결측치 조정

# %%
titanic.loc[titanic['Age']<1.0, 'Cabin'] = 'None'

# %%
titanic.loc[titanic['Cabin']=='None', :]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 831          832         1       2  Richards, Master. George Sibley    male
#
#       Age  Ticket      Fare Cabin Embarked  Family
# 78   0.83  248738   29.0000  None        S       2
# 305  0.92  113781  151.5500  None        S       3
# 469  0.75    2666   19.2583  None        C       3
# 644  0.75    2666   19.2583  None        C       3
# 755  0.67  250649   14.5000  None        S       2
# 803  0.42    2625    8.5167  None        C       1
# ...

# %% [markdown]
# * d

# %%
titanic.select_dtypes(include='number')
# Out:
#      PassengerId  Survived  Pclass   Age     Fare  Family
# 0              1         0       3  22.0   7.2500       1
# 1              2         1       1  38.0  71.2833       1
# 2              3         1       3  26.0   7.9250       0
# 3              4         1       1  35.0  53.1000       1
# 4              5         0       3  35.0   8.0500       0
# ..           ...       ...     ...   ...      ...     ...
# 886          887         0       2  27.0  13.0000       0
# 887          888         1       1  19.0  30.0000       0
# 888          889         0       3   NaN  23.4500       3
# 889          890         1       1  26.0  30.0000       0
# 890          891         0       3  32.0   7.7500       0
#
# [891 rows x 6 columns]

# %% [markdown]
# * 특정한 타입을 가진 column을 가져옴

# %%
df = titanic.select_dtypes(include='float64')
df
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# * data type은 지정가능

# %%
def f1(x): 
    # print(type(x))
    return x.max() - x.min()

# %%
df.apply(f1)
# Out:
# Age      79.5800
# Fare    512.3292
# dtype: float64

# %%
def f2(x):
    if x>30:
        return 0
    else:
        return 1

# %%
df['Age2'] = df['Age'].apply(f2) # 컬럼별로 각각 함수를 적용하여 새로운 column을 생성
df
# Out:
#       Age     Fare  Age2
# 0    22.0   7.2500     1
# 1    38.0  71.2833     0
# 2    26.0   7.9250     1
# 3    35.0  53.1000     0
# 4    35.0   8.0500     0
# ..    ...      ...   ...
# 886  27.0  13.0000     1
# 887  19.0  30.0000     1
# 888   NaN  23.4500     1
# 889  26.0  30.0000     1
# 890  32.0   7.7500     0
#
# [891 rows x 3 columns]

# %% [markdown]
# * series별로 f2 적용

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Cabin Embarked  Family
# 0         A/5 21171   7.2500   NaN        S       1
# 1          PC 17599  71.2833   C85        C       1
# 2  STON/O2. 3101282   7.9250   NaN        S       0
# 3            113803  53.1000  C123        S       1
# 4            373450   8.0500   NaN        S       0

# %%
def f3(x):
    if x == 'male':
        return 1
    else:
        return 0

# %%
titanic.Sex = titanic.Sex.apply(f3)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  \
# 0                            Braund, Mr. Owen Harris    1  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2                             Heikkinen, Miss. Laina    0  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4                           Allen, Mr. William Henry    1  35.0
#
#              Ticket     Fare Cabin Embarked  Family
# 0         A/5 21171   7.2500   NaN        S       1
# 1          PC 17599  71.2833   C85        C       1
# 2  STON/O2. 3101282   7.9250   NaN        S       0
# 3            113803  53.1000  C123        S       1
# 4            373450   8.0500   NaN        S       0

# %%
titanic['Survived'] = titanic['Survived'].apply(lambda x: 'saved' if x == 1 else 'lost')
titanic
# Out:
#      PassengerId Survived  Pclass  \
# 0              1     lost       3
# 1              2    saved       1
# 2              3    saved       3
# 3              4    saved       1
# 4              5     lost       3
# ..           ...      ...     ...
# 886          887     lost       2
# 887          888    saved       1
# 888          889     lost       3
# 889          890    saved       1
# 890          891     lost       3
#
#                                                   Name  Sex   Age  \
# 0                              Braund, Mr. Owen Harris    1  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2                               Heikkinen, Miss. Laina    0  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4                             Allen, Mr. William Henry    1  35.0
# ..                                                 ...  ...   ...
# 886                              Montvila, Rev. Juozas    1  27.0
# ...

# %%
titanic['Survived']  = titanic['Survived'].map({'saved':0, 'lost':1})

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         1       3
# 1              2         0       1
# 2              3         0       3
# 3              4         0       1
# 4              5         1       3
# ..           ...       ...     ...
# 886          887         1       2
# 887          888         0       1
# 888          889         1       3
# 889          890         0       1
# 890          891         1       3
#
#                                                   Name  Sex   Age  \
# 0                              Braund, Mr. Owen Harris    1  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2                               Heikkinen, Miss. Laina    0  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4                             Allen, Mr. William Henry    1  35.0
# ..                                                 ...  ...   ...
# 886                              Montvila, Rev. Juozas    1  27.0
# ...

# %%
x = titanic.dropna()
x.shape
# Out:
# (189, 11)

# %%
x = titanic.fillna(0)
x.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       3
# 1            2         0       1
# 2            3         0       3
# 3            4         0       1
# 4            5         1       3
# 5            6         1       3
# 6            7         1       1
# 7            8         1       3
# 8            9         0       3
# 9           10         0       2
#
#                                                 Name  Sex   Age  \
# 0                            Braund, Mr. Owen Harris    1  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2                             Heikkinen, Miss. Laina    0  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4                           Allen, Mr. William Henry    1  35.0
# 5                                   Moran, Mr. James    1   0.0
# 6                            McCarthy, Mr. Timothy J    1  54.0
# 7                     Palsson, Master. Gosta Leonard    1   2.0
# ...

# %% [markdown]
# * 가능은 하나 좋은 방법이 아님
# * 보통은 대세에 지장이 없는평균값이나 중간값을 넣음

# %%
titanic['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic['Age'] = titanic['Age'].fillna(titanic['Age'].mean())
titanic.isna().sum(axis=0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# Ticket           0
# Fare             0
# Cabin          681
# Embarked         2
# Family           0
# dtype: int64

# %%
titanic['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic['Embarked'] = titanic['Embarked'].fillna('S')

# %%
titanic.isna().sum(axis=0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# Ticket           0
# Fare             0
# Cabin          681
# Embarked         0
# Family           0
# dtype: int64

# %%
titanic['Cabin'].value_counts()
# Out:
# None           7
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 148, dtype: int64

# %% [markdown]
# * cabin은 너무 많이 없어서 사용이 사실상 불가능하므로 날림

# %%
titanic.drop(['Cabin'],axis=1, inplace=True)

# %%
sr = titanic['Embarked'].value_counts()

# %%
import matplotlib.pyplot as plt

# sr.index, sr.valus

# %%
plt.bar(sr.index, sr.values)
plt.title('Embarked')
plt.show()

# %% [markdown]
# * series별로 시각화하는 작업

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       3
# 1            2         0       1
# 2            3         0       3
# 3            4         0       1
# 4            5         1       3
#
#                                                 Name  Sex   Age  \
# 0                            Braund, Mr. Owen Harris    1  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2                             Heikkinen, Miss. Laina    0  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4                           Allen, Mr. William Henry    1  35.0
#
#              Ticket     Fare Embarked  Family
# 0         A/5 21171   7.2500        S       1
# 1          PC 17599  71.2833        C       1
# 2  STON/O2. 3101282   7.9250        S       0
# 3            113803  53.1000        S       1
# 4            373450   8.0500        S       0

# %%
# 남성 승객 나이 평균
man = titanic.loc[titanic['Sex']==1, :]
man['Age'].mean()
# Out:
# 30.505824243042102

# %%
# 여성 승객 나이 평균
woman = titanic.loc[titanic['Sex']==0, :]
woman['Age'].mean()
# Out:
# 28.21673004870738

# %% [markdown]
# ## GroupBy

# %%
data = {
    'city': ['Busan','Busan','Busan','Busan', 'Seoul','Seoul','Seoul'],
    'fruit': ['Apple', 'Orange', 'Banana','Banana' ,'Apple','Apple', 'Banana'],
    'price': [100,200,250,300,150,200,400],
    'quantity': [1,2,3,4,5,6,7]
}

df = pd.DataFrame(data)

# %%
df.groupby('city').price.mean()
# Out:
# city
# Busan    212.5
# Seoul    250.0
# Name: price, dtype: float64

# %%
df.groupby(['city','fruit']).mean()
# Out:
#               price  quantity
# city  fruit
# Busan Apple   100.0       1.0
#       Banana  275.0       3.5
#       Orange  200.0       2.0
# Seoul Apple   175.0       5.5
#       Banana  400.0       7.0

# %%
titanic.groupby('Sex').Age.mean()
# Out:
# Sex
# 0    28.216730
# 1    30.505824
# Name: Age, dtype: float64

# %%
titanic.groupby('Sex').Survived.mean() #살아있는 사람들의 평균 사망률
# Out:
# Sex
# 0    0.257962
# 1    0.811092
# Name: Survived, dtype: float64

# %%
titanic.groupby('Pclass').Survived.mean() #클래스별 사망률
# Out:
# Pclass
# 1    0.370370
# 2    0.527174
# 3    0.757637
# Name: Survived, dtype: float64

# %% [markdown]
# ## 연속형 데이터를 범주형으로 변경

# %%
titanic['AgeClass'] = pd.cut(titanic['Age'], 3, labels = ['child','young','old'])
# Age라는 col를 3개로 child young old 로 나눔
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         1       3
# 1              2         0       1
# 2              3         0       3
# 3              4         0       1
# 4              5         1       3
# ..           ...       ...     ...
# 886          887         1       2
# 887          888         0       1
# 888          889         1       3
# 889          890         0       1
# 890          891         1       3
#
#                                                   Name  Sex        Age  \
# 0                              Braund, Mr. Owen Harris    1  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000
# 2                               Heikkinen, Miss. Laina    0  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000
# 4                             Allen, Mr. William Henry    1  35.000000
# ..                                                 ...  ...        ...
# ...

# %%
titanic['AgeClass'].value_counts()
# Out:
# young    522
# child    319
# old       50
# Name: AgeClass, dtype: int64

# %%
titanic.drop(['Age'], axis=1, inplace = True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         1       3
# 1              2         0       1
# 2              3         0       3
# 3              4         0       1
# 4              5         1       3
# ..           ...       ...     ...
# 886          887         1       2
# 887          888         0       1
# 888          889         1       3
# 889          890         0       1
# 890          891         1       3
#
#                                                   Name  Sex            Ticket  \
# 0                              Braund, Mr. Owen Harris    1         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0          PC 17599
# 2                               Heikkinen, Miss. Laina    0  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0            113803
# 4                             Allen, Mr. William Henry    1            373450
# ...

# %% [markdown]
# ## 문자열 처리

# %%
import numpy as np

data = {
    'Dave':'dave@gmail.com',
    'Steve':'steve',
    'Rob':'rob@gmail.com',
    'Wes': 'wes.@hotmail.com'

}
sr = pd.Series(data)
sr
# Out:
# Dave       dave@gmail.com
# Steve               steve
# Rob         rob@gmail.com
# Wes      wes.@hotmail.com
# dtype: object

# %%
sr.values
# Out:
# array(['dave@gmail.com', 'steve', 'rob@gmail.com', 'wes.@hotmail.com'],
#       dtype=object)

# %%
sr.str.contains('gmail')
# Out:
# Dave      True
# Steve    False
# Rob       True
# Wes      False
# dtype: bool

# %% [markdown]
# * 내가원하는 값이 포함되어있는 여부를 알 수 있음

# %%
sr.str.findall('^[a-zA-Z0-9+-\_.]+@[a-zA-Z0-9-]+\.[a-zA-Z0-9-.]+$')
# Out:
# Dave       [dave@gmail.com]
# Steve                    []
# Rob         [rob@gmail.com]
# Wes      [wes.@hotmail.com]
# dtype: object

# %% [markdown]
# * findall은 비슷한 함수이나 정규표현식을 사용이 가능함

# %% [markdown]
# ## 시계열 데이터

# %%
data = np.random.randn(1000,3)
data.shape

pd.DataFrame(data,
             index=pd.date_range('1/1/2022',periods=1000), 
             columns=['A','B','C'])
# Out:
#                    A         B         C
# 2022-01-01 -0.674325  0.010137 -0.461893
# 2022-01-02 -2.126820 -0.846942 -0.815140
# 2022-01-03  0.034163  0.938610 -0.816456
# 2022-01-04 -1.886338  0.747913 -1.091644
# 2022-01-05 -0.261408  0.093132 -1.680881
# ...              ...       ...       ...
# 2024-09-22 -1.823865 -0.425924 -1.372679
# 2024-09-23  0.707083  0.217886 -0.704566
# 2024-09-24 -0.519531  1.199802  0.209038
# 2024-09-25  0.614510 -0.737573 -0.927096
# 2024-09-26  0.123187 -2.248633  0.538022
#
# [1000 rows x 3 columns]
